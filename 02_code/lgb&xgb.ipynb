# %%
import re
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler
import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostRegressor
import warnings
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, log_loss
warnings.filterwarnings('ignore')

# %%
def cv_model(clf, train_x, train_y, test_x, clf_name):
    folds = 5
    seed = 2020
    kf = KFold(n_splits=folds, shuffle=True, random_state=seed)

    train = np.zeros(train_x.shape[0])
    test = np.zeros(test_x.shape[0])

    cv_scores = []

    for i, (train_index, valid_index) in enumerate(kf.split(train_x, train_y)):
        print('************************************ {} ************************************'.format(str(i+1)))
        trn_x, trn_y, val_x, val_y = train_x.iloc[train_index], train_y[train_index], train_x.iloc[valid_index], train_y[valid_index]

        if clf_name == "lgb":
            train_matrix = clf.Dataset(trn_x, label=trn_y)
            valid_matrix = clf.Dataset(val_x, label=val_y)

            params = {
                'boosting_type': 'gbdt',
                'is_unbalanced':True,
                'objective': 'binary',
                'metric': 'auc',
                'min_child_weight': 7,
                'min_data_in_leaf': 32,
                'max_depth':6,
                'num_leaves': 40,
                'lambda_l2': 10,
                'feature_fraction': 0.8,
                'bagging_fraction': 0.8,
                'pos_bagging_fraction':0.64,
                'neg_bagging_fraction':0.16,
                'bagging_freq': 5,
                'learning_rate': 0.02,
                'seed': 2020,
                'nthread': 28,
                'n_jobs':24,
                #'silent': True,
                'verbose': -1,
            }

            model = clf.train(params, train_matrix, 50000, valid_sets=[train_matrix, valid_matrix], verbose_eval=200,early_stopping_rounds=200)
            val_pred = model.predict(val_x, num_iteration=model.best_iteration)
            test_pred = model.predict(test_x, num_iteration=model.best_iteration)
            
            # print(list(sorted(zip(features, model.feature_importance("gain")), key=lambda x: x[1], reverse=True))[:20])
                
        if clf_name == "xgb":
            train_matrix = clf.DMatrix(trn_x , label=trn_y)
            valid_matrix = clf.DMatrix(val_x , label=val_y)
            test_matrix = clf.DMatrix(test_x)
            
            params = {'booster': 'gbtree',
                      'objective': 'binary:logistic',
                      'eval_metric': 'auc',
                      'gamma': 1,
                      'min_child_weight': 2,
                      'max_depth': 6,
                      'lambda': 10,
                      'subsample': 0.8,
                      'colsample_bytree': 0.8,
                      'colsample_bylevel': 0.8,
                      'scale_pos_weight' : 4,
                      'eta': 0.05,
                      'tree_method': 'exact',
                      'seed': 2020,
                      'nthread': 36,
                      "silent": True
                      }
            
            watchlist = [(train_matrix, 'train'),(valid_matrix, 'eval')]
            
            model = clf.train(params, train_matrix, num_boost_round=50000, evals=watchlist, verbose_eval=200, early_stopping_rounds=200)
            val_pred  = model.predict(valid_matrix, ntree_limit=model.best_ntree_limit)
            test_pred = model.predict(test_matrix , ntree_limit=model.best_ntree_limit)
                 
        if clf_name == "cat":
            params = {'learning_rate': 0.05, 'depth': 5, 'eval_metric':'AUC','l2_leaf_reg': 10, 'bootstrap_type': 'Bernoulli',
                      'od_type': 'Iter', 'od_wait': 50, 'random_seed': 11, 'allow_writing_files': False}
            
            model = clf(iterations=20000, **params)
            model.fit(trn_x, trn_y, eval_set=(val_x, val_y),
                      cat_features=[], use_best_model=True, verbose=500)
            
            val_pred  = model.predict(val_x)
            test_pred = model.predict(test_x)
            
        train[valid_index] = val_pred
        test = test_pred / kf.n_splits
        cv_scores.append(roc_auc_score(val_y, val_pred))
        
        print(cv_scores)
        
    print("%s_scotrainre_list:" % clf_name, cv_scores)
    print("%s_score_mean:" % clf_name, np.mean(cv_scores))
    print("%s_score_std:" % clf_name, np.std(cv_scores))
    return train, test

# %%
def lgb_model(x_train, y_train, x_test):
    lgb_train, lgb_test = cv_model(lgb, x_train, y_train, x_test, "lgb")
    return lgb_train, lgb_test

def xgb_model(x_train, y_train, x_test):
    xgb_train, xgb_test = cv_model(xgb, x_train, y_train, x_test, "xgb")
    return xgb_train, xgb_test

def cat_model(x_train, y_train, x_test):
    cat_train, cat_test = cv_model(CatBoostRegressor, x_train, y_train, x_test, "cat")
    return cat_train, cat_test

# %%
data_train =pd.read_csv('../01_inter_data/train_cat_cleaned.csv')
data_test_a = pd.read_csv('../01_inter_data/test_a_cat_cleaned.csv')

# %%
data_test_a_id = pd.read_csv('../00_data/testA.csv')
test_id = data_test_a_id['id']

# %%
from category_encoders import OrdinalEncoder
cate_features = ['grade', 'subGrade']

for i in cate_features:
    Le = LabelEncoder()
    data = pd.concat([data_train,data_test_a])
    Le.fit(data[i])
    data_train[i] = Le.transform(data_train[i])
    data_test_a[i] = Le.transform(data_test_a[i])
#Te.fit(data_train[cate_features],data_train['isDefault'])
#te_cols = Te.transform(data[cate_features])

# %%
features = [f for f in data_train.columns if f not in ['id','isDefault']]
x_train = data_train[features]
x_test = data_test_a[features]
y_train = data_train['isDefault']

# %%
data_train.info(max_cols=1000)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800000 entries, 0 to 799999
# Data columns (total 46 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  800000 non-null  int64
#  1   loanAmnt            800000 non-null  float64
#  2   term                800000 non-null  int64
#  3   interestRate        800000 non-null  float64
#  4   installment         800000 non-null  float64
#  5   grade               800000 non-null  int32
#  6   subGrade            800000 non-null  int32
#  7   employmentTitle     800000 non-null  float64
#  8   employmentLength    800000 non-null  float64
#  9   homeOwnership       800000 non-null  int64
#  10  annualIncome        800000 non-null  float64
#  11  verificationStatus  800000 non-null  int64
#  12  issueDate           800000 non-null  int64
#  13  isDefault           800000 non-null  int64
#  14  purpose             800000 non-null  int64
#  15  postCode            800000 non-null  float64
#  16  regionCode          800000 non-null  int64
#  17  dti                 800000 non-null  float64
#  18  delinquency_2years  800000 non-null  float64
#  19  ficoRangeLow        800000 non-null  float64
#  20  ficoRangeHigh       800000 non-null  float64
#  21  openAcc             800000 non-null  float64
#  22  pubRec              800000 non-null  float64
#  23  pubRecBankruptcies  800000 non-null  float64
#  24  revolBal            800000 non-null  float64
#  25  revolUtil           800000 non-null  float64
#  26  totalAcc            800000 non-null  float64
#  27  initialListStatus   800000 non-null  int64
#  28  applicationType     800000 non-null  int64
#  29  earliesCreditLine   800000 non-null  int64
#  30  title               800000 non-null  float64
#  31  n0                  800000 non-null  float64
#  32  n1                  800000 non-null  float64
#  33  n2                  800000 non-null  float64
#  34  n4                  800000 non-null  float64
#  35  n5                  800000 non-null  float64
#  36  n6                  800000 non-null  float64
#  37  n7                  800000 non-null  float64
#  38  n8                  800000 non-null  float64
#  39  n9                  800000 non-null  float64
#  40  n10                 800000 non-null  float64
#  41  n11                 800000 non-null  float64
#  42  n12                 800000 non-null  float64
#  43  n13                 800000 non-null  float64
#  44  n14                 800000 non-null  float64
#  45  missrate            800000 non-null  float64
# dtypes: float64(33), int32(2), int64(11)
# memory usage: 274.7 MB

# %%
lgb_train,lgb_test = lgb_model(x_train, y_train, x_test)
# Out:
# ************************************ 1 ************************************
# [LightGBM] [Warning] Unknown parameter: is_unbalanced
# [LightGBM] [Warning] num_threads is set with n_jobs=24, nthread=28 will be ignored. Current value: num_threads=24
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.72971	valid_1's auc: 0.728054
# [400]	training's auc: 0.737012	valid_1's auc: 0.732556
# [600]	training's auc: 0.741763	valid_1's auc: 0.734438
# [800]	training's auc: 0.74577	valid_1's auc: 0.735611
# [1000]	training's auc: 0.749158	valid_1's auc: 0.736342
# [1200]	training's auc: 0.75212	valid_1's auc: 0.736772
# [1400]	training's auc: 0.754871	valid_1's auc: 0.737101
# [1600]	training's auc: 0.757465	valid_1's auc: 0.73739
# [1800]	training's auc: 0.759803	valid_1's auc: 0.737458
# [2000]	training's auc: 0.762203	valid_1's auc: 0.737604
# Early stopping, best iteration is:
# [1933]	training's auc: 0.761414	valid_1's auc: 0.737624
# [0.7376242733761404]
# ************************************ 2 ************************************
# [LightGBM] [Warning] Unknown parameter: is_unbalanced
# [LightGBM] [Warning] num_threads is set with n_jobs=24, nthread=28 will be ignored. Current value: num_threads=24
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.730748	valid_1's auc: 0.724233
# [400]	training's auc: 0.737643	valid_1's auc: 0.728421
# [600]	training's auc: 0.742493	valid_1's auc: 0.730665
# [800]	training's auc: 0.746289	valid_1's auc: 0.731979
# [1000]	training's auc: 0.749625	valid_1's auc: 0.732819
# [1200]	training's auc: 0.752733	valid_1's auc: 0.733491
# [1400]	training's auc: 0.755391	valid_1's auc: 0.733896
# [1600]	training's auc: 0.757976	valid_1's auc: 0.734248
# [1800]	training's auc: 0.760469	valid_1's auc: 0.734452
# [2000]	training's auc: 0.762691	valid_1's auc: 0.734612
# [2200]	training's auc: 0.765016	valid_1's auc: 0.734738
# [2400]	training's auc: 0.767232	valid_1's auc: 0.73484
# Early stopping, best iteration is:
# [2338]	training's auc: 0.766571	valid_1's auc: 0.734883
# [0.7376242733761404, 0.7348826585710755]
# ************************************ 3 ************************************
# [LightGBM] [Warning] Unknown parameter: is_unbalanced
# [LightGBM] [Warning] num_threads is set with n_jobs=24, nthread=28 will be ignored. Current value: num_threads=24
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.729986	valid_1's auc: 0.727526
# [400]	training's auc: 0.736885	valid_1's auc: 0.731761
# [600]	training's auc: 0.741808	valid_1's auc: 0.734076
# [800]	training's auc: 0.745742	valid_1's auc: 0.735557
# [1000]	training's auc: 0.749017	valid_1's auc: 0.736259
# [1200]	training's auc: 0.752118	valid_1's auc: 0.736882
# [1400]	training's auc: 0.754821	valid_1's auc: 0.737429
# [1600]	training's auc: 0.757555	valid_1's auc: 0.737626
# [1800]	training's auc: 0.759968	valid_1's auc: 0.737839
# [2000]	training's auc: 0.76229	valid_1's auc: 0.737975
# [2200]	training's auc: 0.764629	valid_1's auc: 0.737957
# [2400]	training's auc: 0.766962	valid_1's auc: 0.738181
# [2600]	training's auc: 0.768997	valid_1's auc: 0.738271
# [2800]	training's auc: 0.770992	valid_1's auc: 0.738256
# Early stopping, best iteration is:
# [2719]	training's auc: 0.770235	valid_1's auc: 0.738302
# [0.7376242733761404, 0.7348826585710755, 0.7383015447602914]
# ************************************ 4 ************************************
# [LightGBM] [Warning] Unknown parameter: is_unbalanced
# [LightGBM] [Warning] num_threads is set with n_jobs=24, nthread=28 will be ignored. Current value: num_threads=24
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.72996	valid_1's auc: 0.726275
# [400]	training's auc: 0.736934	valid_1's auc: 0.730792
# [600]	training's auc: 0.741779	valid_1's auc: 0.733246
# [800]	training's auc: 0.745498	valid_1's auc: 0.734636
# [1000]	training's auc: 0.748774	valid_1's auc: 0.735572
# [1200]	training's auc: 0.751857	valid_1's auc: 0.73615
# [1400]	training's auc: 0.754673	valid_1's auc: 0.736659
# [1600]	training's auc: 0.757241	valid_1's auc: 0.736976
# [1800]	training's auc: 0.759705	valid_1's auc: 0.7373
# [2000]	training's auc: 0.76206	valid_1's auc: 0.737528
# [2200]	training's auc: 0.764362	valid_1's auc: 0.737662
# [2400]	training's auc: 0.76652	valid_1's auc: 0.737673
# [2600]	training's auc: 0.76861	valid_1's auc: 0.737709
# [2800]	training's auc: 0.770687	valid_1's auc: 0.737766
# [3000]	training's auc: 0.772689	valid_1's auc: 0.737858
# Early stopping, best iteration is:
# [2979]	training's auc: 0.772487	valid_1's auc: 0.737859
# [0.7376242733761404, 0.7348826585710755, 0.7383015447602914, 0.7378587795978446]
# ************************************ 5 ************************************
# [LightGBM] [Warning] Unknown parameter: is_unbalanced
# [LightGBM] [Warning] num_threads is set with n_jobs=24, nthread=28 will be ignored. Current value: num_threads=24
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.730288	valid_1's auc: 0.725732
# [400]	training's auc: 0.737476	valid_1's auc: 0.73011
# [600]	training's auc: 0.742385	valid_1's auc: 0.732253
# [800]	training's auc: 0.746181	valid_1's auc: 0.733563
# [1000]	training's auc: 0.749469	valid_1's auc: 0.73459
# [1200]	training's auc: 0.752354	valid_1's auc: 0.735112
# [1400]	training's auc: 0.755166	valid_1's auc: 0.735643
# [1600]	training's auc: 0.757785	valid_1's auc: 0.73586
# [1800]	training's auc: 0.760162	valid_1's auc: 0.736164
# [2000]	training's auc: 0.76247	valid_1's auc: 0.736311
# [2200]	training's auc: 0.764834	valid_1's auc: 0.736494
# [2400]	training's auc: 0.767063	valid_1's auc: 0.736674
# [2600]	training's auc: 0.769176	valid_1's auc: 0.736699
# Early stopping, best iteration is:
# [2465]	training's auc: 0.767803	valid_1's auc: 0.73672
# [0.7376242733761404, 0.7348826585710755, 0.7383015447602914, 0.7378587795978446, 0.7367204623117358]
# lgb_scotrainre_list: [0.7376242733761404, 0.7348826585710755, 0.7383015447602914, 0.7378587795978446, 0.7367204623117358]
# lgb_score_mean: 0.7370775437234176
# lgb_score_std: 0.001212637564111132

# %%
xgb_train, xgb_test= xgb_model(x_train, y_train, x_test)
# Out:
# ************************************ 1 ************************************
# [21:49:55] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-auc:0.70693	eval-auc:0.70742
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 200 rounds.
# [200]	train-auc:0.74362	eval-auc:0.73375
# [400]	train-auc:0.75565	eval-auc:0.73643
# [600]	train-auc:0.76476	eval-auc:0.73720
# [800]	train-auc:0.77253	eval-auc:0.73759
# [1000]	train-auc:0.77977	eval-auc:0.73776
# Stopping. Best iteration:
# [972]	train-auc:0.77885	eval-auc:0.73782
#
# [0.7378169771878842]
# ************************************ 2 ************************************
# [21:54:14] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-auc:0.70765	eval-auc:0.70301
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 200 rounds.
# [200]	train-auc:0.74415	eval-auc:0.72973
# [400]	train-auc:0.75619	eval-auc:0.73245
# [600]	train-auc:0.76502	eval-auc:0.73360
# [800]	train-auc:0.77286	eval-auc:0.73417
# [1000]	train-auc:0.78050	eval-auc:0.73429
# [1200]	train-auc:0.78751	eval-auc:0.73440
# [1400]	train-auc:0.79410	eval-auc:0.73433
# Stopping. Best iteration:
# [1354]	train-auc:0.79261	eval-auc:0.73443
#
# [0.7378169771878842, 0.7344279166901719]
# ************************************ 3 ************************************
# [22:00:00] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-auc:0.70703	eval-auc:0.70521
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 200 rounds.
# [200]	train-auc:0.74325	eval-auc:0.73303
# [400]	train-auc:0.75561	eval-auc:0.73621
# [600]	train-auc:0.76455	eval-auc:0.73724
# [800]	train-auc:0.77258	eval-auc:0.73760
# [1000]	train-auc:0.77967	eval-auc:0.73776
# [1200]	train-auc:0.78682	eval-auc:0.73779
# Stopping. Best iteration:
# [1136]	train-auc:0.78454	eval-auc:0.73782
#
# [0.7378169771878842, 0.7344279166901719, 0.7378177155290202]
# ************************************ 4 ************************************
# [22:04:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-auc:0.70712	eval-auc:0.70578
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 200 rounds.
# [200]	train-auc:0.74325	eval-auc:0.73192
# [400]	train-auc:0.75563	eval-auc:0.73537
# [600]	train-auc:0.76472	eval-auc:0.73648
# [800]	train-auc:0.77245	eval-auc:0.73679
# [1000]	train-auc:0.77999	eval-auc:0.73702
# [1200]	train-auc:0.78698	eval-auc:0.73697
# Stopping. Best iteration:
# [1068]	train-auc:0.78254	eval-auc:0.73712
#
# [0.7378169771878842, 0.7344279166901719, 0.7378177155290202, 0.7371178861390167]
# ************************************ 5 ************************************
# [22:09:44] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-auc:0.70713	eval-auc:0.70452
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 200 rounds.
# [200]	train-auc:0.74358	eval-auc:0.73124
# [400]	train-auc:0.75571	eval-auc:0.73434
# [600]	train-auc:0.76516	eval-auc:0.73559
# [800]	train-auc:0.77295	eval-auc:0.73610
# [1000]	train-auc:0.78057	eval-auc:0.73647
# [1200]	train-auc:0.78733	eval-auc:0.73645
# [1400]	train-auc:0.79365	eval-auc:0.73648
# Stopping. Best iteration:
# [1254]	train-auc:0.78912	eval-auc:0.73651
#
# [0.7378169771878842, 0.7344279166901719, 0.7378177155290202, 0.7371178861390167, 0.736510272171595]
# xgb_scotrainre_list: [0.7378169771878842, 0.7344279166901719, 0.7378177155290202, 0.7371178861390167, 0.736510272171595]
# xgb_score_mean: 0.7367381535435377
# xgb_score_std: 0.0012540044352790023

# %%
#将三个模型的output做voting
test_result =pd.concat([test_id,pd.DataFrame(lgb_test),pd.DataFrame(cat_test)],axis = 1)
test_result.columns = ['id','isDefault_lgb','isDefault_cat']

# %%
test_result.to_csv('../03_result/testA_pred_2.csv',index = False)

# %%
lgb_test_result = pd.concat([test_id,pd.DataFrame(lgb_test)],axis = 1)
lgb_test_result.to_csv('../03_result/testA_pred_lgb7370.csv')
lgb_train_result = pd.concat([data_train.id,pd.DataFrame(lgb_train),data_train.isDefault],axis = 1)
lgb_train_result.to_csv('../03_result/trainA_pred_lgb7370.csv')

# %%
# voting
#xgb_result = pd.read_csv('../03_result/testA_pred.csv')

# %%
total_result = xgb_result.merge(test_result,on = 'id')

# %%
total_result['isDefault_xgb'] =  total_result['isDefault']

# %%
total_result['isDefault'] = total_result['isDefault_xgb']*0.4 + total_result['isDefault_lgb']*0.3 +total_result['isDefault_cat']*0.3

# %%
total_result[['id','isDefault']].to_csv('../03_result/testA_pred_stack.csv',index = False)

# %%
test_result[['id','isDefault_lgb']].to_csv('../03_result/testA_pred_2.csv',index = False)

# %%
test_result[['id','isDefault_cat']].to_csv('../03_result/testA_pred_3.csv',index = False)

# %%
test_result
# Out:
#             id  isDefault_lgb  isDefault_cat
# 0       800000       0.012237       0.012668
# 1       800001       0.057759       0.066223
# 2       800002       0.119079       0.113430
# 3       800003       0.060883       0.062080
# 4       800004       0.075759       0.071827
# ...        ...            ...            ...
# 199995  999995       0.033294       0.033081
# 199996  999996       0.005441       0.006606
# 199997  999997       0.028636       0.035593
# 199998  999998       0.053191       0.046561
# 199999  999999       0.004440      -0.001332
#
# [200000 rows x 3 columns]

# %%
total_result
# Out:
#             id  isDefault  isDefault_lgb  isDefault_cat  isDefault_xgb
# 0       800000   0.013324       0.012237       0.012668       0.014630
# 1       800001   0.063443       0.057759       0.066223       0.065620
# 2       800002   0.119657       0.119079       0.113430       0.124761
# 3       800003   0.061649       0.060883       0.062080       0.061900
# 4       800004   0.068613       0.075759       0.071827       0.060845
# ...        ...        ...            ...            ...            ...
# 199995  999995   0.031765       0.033294       0.033081       0.029632
# 199996  999996   0.006010       0.005441       0.006606       0.005989
# 199997  999997   0.032861       0.028636       0.035593       0.033981
# 199998  999998   0.049142       0.053191       0.046561       0.048041
# 199999  999999   0.003072       0.004440      -0.001332       0.005350
#
# [200000 rows x 5 columns]
